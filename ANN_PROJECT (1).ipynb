# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.utils import to_categorical

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (60000, 28, 28)
# Test shape: (10000, 28, 28)

# %%
# Normalize (0 → 1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
model = Sequential([
    Input(shape=(28, 28)),   # input layer

    Flatten(),

    Dense(128, activation='relu'),
    Dense(64, activation='relu'),

    Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8905 - loss: 0.3804 - val_accuracy: 0.9430 - val_loss: 0.1915
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9534 - loss: 0.1564 - val_accuracy: 0.9583 - val_loss: 0.1425
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9684 - loss: 0.1072 - val_accuracy: 0.9674 - val_loss: 0.1055
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9767 - loss: 0.0799 - val_accuracy: 0.9695 - val_loss: 0.1033
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9808 - loss: 0.0636 - val_accuracy: 0.9675 - val_loss: 0.1071
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9854 - loss: 0.0498 - val_accuracy: 0.9729 - val_loss: 0.0960
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9879 - loss: 0.0401 - val_accuracy: 0.9732 - val_loss: 0.0885
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9897 - loss: 0.0332 - val_accuracy: 0.9734 - val_loss: 0.0921
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9924 - loss: 0.0265 - val_accuracy: 0.9735 - val_loss: 0.1000
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9938 - loss: 0.0217 - val_accuracy: 0.9765 - val_loss: 0.0883

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9783 - loss: 0.0716
# Test Loss: 0.07164067775011063
# Test Accuracy: 0.9782999753952026

# %%
plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Loss Curve")
# Out:
# Text(0.5, 1.0, 'Loss Curve')

# %%
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title("Accuracy Curve")

plt.show()

# %%
model1 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model1.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

history1 = model1.fit(X_train, y_train,
                      epochs=10,
                      batch_size=128,
                      validation_split=0.2)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8901 - loss: 0.3980 - val_accuracy: 0.9392 - val_loss: 0.2153
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9478 - loss: 0.1805 - val_accuracy: 0.9572 - val_loss: 0.1530
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9625 - loss: 0.1319 - val_accuracy: 0.9611 - val_loss: 0.1324
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9701 - loss: 0.1036 - val_accuracy: 0.9662 - val_loss: 0.1164
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9765 - loss: 0.0839 - val_accuracy: 0.9681 - val_loss: 0.1079
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9804 - loss: 0.0700 - val_accuracy: 0.9688 - val_loss: 0.1013
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9829 - loss: 0.0595 - val_accuracy: 0.9686 - val_loss: 0.1005
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9863 - loss: 0.0499 - val_accuracy: 0.9714 - val_loss: 0.0959
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9880 - loss: 0.0428 - val_accuracy: 0.9710 - val_loss: 0.0942
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9899 - loss: 0.0368 - val_accuracy: 0.9733 - val_loss: 0.0881

# %%
model2 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
               loss='categorical_crossentropy',
               metrics=['accuracy'])

history2 = model2.fit(X_train, y_train,
                      epochs=10,
                      batch_size=128,
                      validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8976 - loss: 0.3835 - val_accuracy: 0.9488 - val_loss: 0.1820
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9562 - loss: 0.1512 - val_accuracy: 0.9635 - val_loss: 0.1280
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9695 - loss: 0.1039 - val_accuracy: 0.9695 - val_loss: 0.1060
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9779 - loss: 0.0776 - val_accuracy: 0.9706 - val_loss: 0.0995
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9829 - loss: 0.0586 - val_accuracy: 0.9732 - val_loss: 0.0937
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9860 - loss: 0.0473 - val_accuracy: 0.9747 - val_loss: 0.0885
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9898 - loss: 0.0373 - val_accuracy: 0.9759 - val_loss: 0.0846
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9920 - loss: 0.0294 - val_accuracy: 0.9723 - val_loss: 0.0954
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9933 - loss: 0.0242 - val_accuracy: 0.9770 - val_loss: 0.0856
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9957 - loss: 0.0181 - val_accuracy: 0.9762 - val_loss: 0.0849

# %%
print("Model 1 Evaluation:")
model1.evaluate(X_test, y_test)

print("Model 2 Evaluation:")
model2.evaluate(X_test, y_test)
# Out:
# Model 1 Evaluation:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9761 - loss: 0.0790
# Model 2 Evaluation:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9791 - loss: 0.0705
# [0.07047881931066513, 0.9790999889373779]
