# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Train shape: (60000, 28, 28)
# Test shape: (10000, 28, 28)

# %%
# Normalize (0 → 1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
model = Sequential([
    Input(shape=(28, 28)),   # input layer بطريقة صحيحة

    Flatten(),

    Dense(128, activation='relu'),
    Dense(64, activation='relu'),

    Dense(10, activation='softmax')
])

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.8930 - loss: 0.3804 - val_accuracy: 0.9473 - val_loss: 0.1926
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9533 - loss: 0.1601 - val_accuracy: 0.9575 - val_loss: 0.1471
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9661 - loss: 0.1148 - val_accuracy: 0.9629 - val_loss: 0.1217
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9733 - loss: 0.0888 - val_accuracy: 0.9683 - val_loss: 0.1066
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9797 - loss: 0.0687 - val_accuracy: 0.9697 - val_loss: 0.1007
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9829 - loss: 0.0569 - val_accuracy: 0.9666 - val_loss: 0.1142
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9868 - loss: 0.0439 - val_accuracy: 0.9724 - val_loss: 0.0965
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9887 - loss: 0.0383 - val_accuracy: 0.9721 - val_loss: 0.0960
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9911 - loss: 0.0302 - val_accuracy: 0.9755 - val_loss: 0.0892
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9922 - loss: 0.0258 - val_accuracy: 0.9726 - val_loss: 0.0993

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9742 - loss: 0.0931
# Test Loss: 0.09305652976036072
# Test Accuracy: 0.9742000102996826

# %%
plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Loss Curve")

# Accuracy
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title("Accuracy Curve")

plt.show()

# %%
model1 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model1.compile(optimizer='adam',
               loss='categorical_crossentropy',
               metrics=['accuracy'])

history1 = model1.fit(X_train, y_train,
                      epochs=10,
                      batch_size=128,
                      validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8901 - loss: 0.4011 - val_accuracy: 0.9422 - val_loss: 0.2133
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9476 - loss: 0.1878 - val_accuracy: 0.9556 - val_loss: 0.1550
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9616 - loss: 0.1350 - val_accuracy: 0.9613 - val_loss: 0.1306
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9701 - loss: 0.1050 - val_accuracy: 0.9662 - val_loss: 0.1149
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9758 - loss: 0.0840 - val_accuracy: 0.9692 - val_loss: 0.1049
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9808 - loss: 0.0695 - val_accuracy: 0.9716 - val_loss: 0.0954
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9839 - loss: 0.0578 - val_accuracy: 0.9718 - val_loss: 0.0927
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9866 - loss: 0.0495 - val_accuracy: 0.9737 - val_loss: 0.0899
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9884 - loss: 0.0419 - val_accuracy: 0.9751 - val_loss: 0.0841
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9908 - loss: 0.0349 - val_accuracy: 0.9702 - val_loss: 0.0907

# %%
model2 = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0005),
               loss='categorical_crossentropy',
               metrics=['accuracy'])

history2 = model2.fit(X_train, y_train,
                      epochs=10,
                      batch_size=128,
                      validation_split=0.2)
# Out:
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.8902 - loss: 0.3947 - val_accuracy: 0.9507 - val_loss: 0.1818
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9563 - loss: 0.1523 - val_accuracy: 0.9597 - val_loss: 0.1342
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.9698 - loss: 0.1056 - val_accuracy: 0.9686 - val_loss: 0.1123
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9769 - loss: 0.0800 - val_accuracy: 0.9693 - val_loss: 0.0971
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9823 - loss: 0.0614 - val_accuracy: 0.9725 - val_loss: 0.0891
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9858 - loss: 0.0492 - val_accuracy: 0.9722 - val_loss: 0.0877
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9894 - loss: 0.0378 - val_accuracy: 0.9764 - val_loss: 0.0770
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9917 - loss: 0.0296 - val_accuracy: 0.9752 - val_loss: 0.0797
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9935 - loss: 0.0240 - val_accuracy: 0.9762 - val_loss: 0.0824
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9949 - loss: 0.0192 - val_accuracy: 0.9778 - val_loss: 0.0782

# %%
print("Model 1 Evaluation:")
model1.evaluate(X_test, y_test)

print("Model 2 Evaluation:")
model2.evaluate(X_test, y_test)
# Out:
# Model 1 Evaluation:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9725 - loss: 0.0848
# Model 2 Evaluation:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9784 - loss: 0.0743
# [0.07428742200136185, 0.9783999919891357]
